# %% [markdown]
# # Data Distribution vs. Sampling Distribution: A Comprehensive Exploration
# The field of statistics is replete with concepts and methodologies that enable us to make sense of data, draw inferences, and model the world around us. Among these foundational concepts, the understanding of Data Distribution and Sampling Distribution stands paramount. These distributions, although distinct in their nature, are intertwined in a dance of numbers that reveals the underlying patterns, tendencies, and characteristics of data.
#
# In this exploration, we shall embark on a journey to unravel the mathematical elegance, practical applications, and philosophical insights that define Data Distribution and Sampling Distribution. We will delve into their definitions, mathematical representations, properties, and real-world implications, illuminating the path for statisticians, data scientists, researchers, and enthusiasts alike.

# %% [markdown]
# Understanding the distinction between Data Distribution (also known as Population Distribution) and Sampling Distribution is a fundamental prerequisite in statistical analysis. This differentiation becomes vital when exploring advanced statistical concepts such as the Central Limit Theorem, Standard Deviation, and Standard Error.
#
# In the ensuing sections of this exploration, we shall meticulously dissect the aforementioned concepts, along with an insightful examination of Bootstrapping as a method to estimate the Sampling Distribution. Specifically, our journey will encompass the following key areas:
#
# + Data Distribution (or Population Distribution)
# + Sampling Distribution
# + Central Limit Theorem (CLT)
# + Standard Error and its Relationship with Standard Deviation
# + Bootstrapping

# %% [markdown]
# ## Data Distribution
# The realm of statistics is intricately woven around the practice of drawing inferences from samples that represent a broader population. Therefore, a clear demarcation between the analysis performed on the original data and the analysis conducted on its samples is imperative.
#
# Let's commence by defining the concept of Data Distribution:
#
# 💡 Data Distribution: A statistical representation that encapsulates the frequency distribution of individual data points within the original dataset.
#
# ## Generation of Data
# To vividly illustrate the relationship between Data Distribution and Sampling Distribution, we shall begin by generating random skewed data that will result in a non-normal (non-Gaussian) distribution. The rationale behind selecting non-normal data is to provide a more pronounced contrast that underscores the interplay between these two critical distributions.
#
# We will now proceed to import the necessary Python plotting libraries and generate a dataset characterized by right-skewed distribution.

# %%
import numpy as np
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import resample # If bootstrapping is to be performed

# %%
# Setting a random seed for reproducibility
np.random.seed(42)

# Generating right-skewed data using the exponential distribution
data = np.random.exponential(scale=2, size=1000)

# Plotting a histogram to visualize the distribution
plt.hist(data, bins=20, edgecolor='black')
plt.title('Right-Skewed Data Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()
